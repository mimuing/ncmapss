# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import warnings
from glob import glob
from sklearn.model_selection import train_test_split
import os
import h5py
import time
from datetime import timedelta
import seaborn as sns
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

# %%
# moving_average(data smoothing)
def moving_average_ratio(data, window_ratio):
    window_size = int(window_ratio * len(data))
    half_window = window_size // 2
    kernel = np.ones(window_size) / window_size
    smoothed_data = np.convolve(data.values, kernel, mode='same')
    smoothed_series = pd.Series(smoothed_data, index=data.index)
    # 처음과 끝 부분 처리
    smoothed_series.iloc[:half_window] = data.iloc[:half_window].mean()
    smoothed_series.iloc[-half_window:] = data.iloc[-half_window:].mean()
    
    return smoothed_series

# Phase data 추가
def getPhaseData(df) :
    df = df.copy()
    # altitude와 altitudeShifted 계산
    altitude = df['alt'].iloc[:-1].reset_index(drop=True) # index reset
    altitudeShifted = df['alt'].iloc[1:].reset_index(drop=True) # index reset
    # alt 변화 계산
    altChange = altitudeShifted - altitude
    # AltChange 데이터 smoothing
    smoothedAltChange = moving_average_ratio(altChange, 0.05)
    smoothedAltChange = np.array(smoothedAltChange)
    # Cruise/Climb/Descend 영역 인덱스 생성
    cruiseIdx = np.logical_and(np.greater_equal(smoothedAltChange, -2), np.less_equal(smoothedAltChange, 2))
    climbIdx = np.greater(smoothedAltChange, 2)
    descendIdx = np.less(smoothedAltChange, -2)
    # altitude 데이터 가져오기
    df = df[:-1] # altChange 계산결과와 맞추기 위해 행 하나 줄임
    df.loc[:,"climb"] = climbIdx
    df.loc[:,"cruise"] = cruiseIdx
    df.loc[:,"descend"] = descendIdx
    df = df.loc[(df['climb'] == True)|(df['cruise'] == True)|(df['descend'] == True)]
    
    return df

# 파생 변수 생성
def gen_additional_var(df) :
    df['hpc_lpc_temp'] = (df['T30'] - df['T24']).abs()/df['T30']
    df['hpt_hpc_temp'] = (df['T48'] - df['T30']).abs()/df['T48']
    df['lpt_hpt_temp'] = (df['T50'] - df['T48']).abs()/df['T50']

    df['lpc_fan_press'] = (df['P24'] - df['P21']).abs()/df['P24']
    df['hpc_lpc_press'] = (df['P30'] - df['P24']).abs()/df['P30']
    df['hpt_hpc_press'] = (df['P45'] - df['P30']).abs()/df['P45']
    df['lpt_hpt_press'] = (df['P50'] - df['P45']).abs()/df['P50']

    df['hpc_lpc_temp_ratio'] = (df['T30'] / df['T24'])
    df['hpt_hpc_temp_ratio'] = (df['T48'] / df['T30'])
    df['lpt_hpt_temp_ratio'] = (df['T50'] / df['T48'])

    df['lpc_fan_press_ratio'] = (df['P24'] / df['P21'])
    df['hpc_lpc_press_ratio'] = (df['P30'] / df['P24'])
    df['hpt_hpc_press_ratio'] = (df['P45'] / df['P30'])
    df['lpt_hpt_press_ratio'] = (df['P50'] / df['P45'])
    
    df['hpt_entry_temp_drop'] = (df['T40']- df['T48']).abs() / df['T40']
    df['lpt_entry_temp_drop'] = (df['T48'] - df['T50']).abs() / df['T48']
    df['hpt_entry_press_ratio'] = df['P45']/ df['P40']
    df['fan_exit_press'] = df['SmFan'] / df['P21']
    df['hpc_exit_press'] = (df['SmHPC']) / df['Ps30']
    df['hpc_entry_temp'] = df['SmLPC'] / df['T2']
    
    return df

# Health 데이터 라벨링
def label_data(df):
    df = df.copy()
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 2)] =  'hpt'
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 5)] =  'hpt'
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 10)] = 'hpt'
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 16)] = 'hpt+lpt'
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 18)] = 'hpt+lpt'
    df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 20)] = 'hpt+lpt'
    # healthy 변수 추가
    df['tartget'] = df['failure_mode']
    df['tartget'].loc[df['hs'] == 1] = 'healthy'
    
    df['hpt_yn'] = 0
    df['lpt_yn'] = 0
    df['fan_yn'] = 0
    df['hpc_yn'] = 0
    df['lpc_yn'] = 0
    
    df['hpt_yn'].loc[(df['tartget'] == 'hpt') | (df['tartget'] == 'hpt+lpt') | (df['tartget'] == 'all')] = 1
    df['lpt_yn'].loc[(df['tartget'] == 'lpt') | (df['tartget'] == 'hpt+lpt') | (df['tartget'] == 'all')] = 1
    df['fan_yn'].loc[(df['tartget'] == 'fan') | (df['tartget'] == 'all')] = 1
    df['hpc_yn'].loc[(df['tartget'] == 'hpc') | (df['tartget'] == 'hpc+lpc') | (df['tartget'] == 'all')] = 1
    df['lpc_yn'].loc[(df['tartget'] == 'hpc+lpc') | (df['tartget'] == 'all')] = 1
    
    return df

# 각 컬럼에서 data smoothing 후, min, max
def generate_max_min(df, window):
    # 이동평균 계산
    rolling_mean_df = df.rolling(window=window).mean()
    # 최대값 계산
    max_df = pd.DataFrame(rolling_mean_df.max()).transpose()
    max_df.columns = df.columns + '_max'
    # 최소값 계산
    min_df = pd.DataFrame(rolling_mean_df.min()).transpose()
    min_df.columns = df.columns + '_min'
    return pd.concat([max_df, min_df], axis=1)

def generate_mean(df, window) :
    df = df.rolling(window=window).mean()
    mean_df = pd.DataFrame(df.mean()).transpose()
    mean_df.columns = df.columns + '_mean'    
    return mean_df

def generate_median(df, window) :
    df = df.rolling(window=window).mean()
    median_df = pd.DataFrame(df.median()).transpose()
    median_df.columns = df.columns + '_median'    
    return median_df

def generate_std(df, window) :
    df = df.rolling(window=window).mean()
    std_df = pd.DataFrame(df.std()).transpose()
    std_df.columns = df.columns + '_std'    
    return std_df

def data_prp(df, use_columns, word):
    df = df.copy()
    df_prp = pd.DataFrame()
    t_list = df[[word+'file_name',word+'unit',word+'cycle',word+'Fc',word+'fileNo',
                     word+'hpt_yn', word+'lpt_yn', word+'fan_yn', word+'hpc_yn', word+'lpc_yn', 
                     word+'flight_time(min)',word+'RUL']].drop_duplicates().reset_index(drop=True)
    
    for i in range(0,t_list.shape[0]):
        print(str(i)+"/"+str(t_list.shape[0]))
        # 해당 데이터셋에서 xs, xv, 신규 파생 변수만 집계값 사용
        df_prp_tmp = df[use_columns].loc[(df[word+'file_name'] == t_list[word+'file_name'][i]) 
                                             & (df[word+'unit'] == t_list[word+'unit'][i]) 
                                             & (df[word+'cycle'] == t_list[word+'cycle'][i])]
        join_df = pd.DataFrame()        
        # max, min 값
        df_minmax = generate_max_min(df_prp_tmp,window=5)
        join_df = df_minmax
        # mean 
        df_mean = generate_mean(df_prp_tmp,window=5)
        join_df = pd.concat([join_df, df_mean], axis=1)
        # median 
        df_median = generate_median(df_prp_tmp,window=5)
        join_df = pd.concat([join_df, df_median], axis=1)
        # std
        df_std = generate_std(df_prp_tmp,window=5)
        join_df = pd.concat([join_df, df_std], axis=1)
        # 맨 마지막에 hs, cylce, unit 추가
        join_df[word+'flight_time(min)'] = t_list[word+'flight_time(min)'][i]
        join_df[word+'unit'] = t_list[word+'unit'][i]
        join_df[word+'cycle'] = t_list[word+'cycle'][i]
        join_df[word+'Fc'] = t_list[word+'Fc'][i]
        join_df[word+'fileNo'] = t_list[word+'fileNo'][i]
        join_df[word+'hpt_yn'] = t_list[word+'hpt_yn'][i]
        join_df[word+'lpt_yn'] = t_list[word+'lpt_yn'][i]
        join_df[word+'fan_yn'] = t_list[word+'fan_yn'][i]
        join_df[word+'hpc_yn'] = t_list[word+'hpc_yn'][i]
        join_df[word+'lpc_yn'] = t_list[word+'lpc_yn'][i]    
        join_df[word+'RUL'] = t_list[word+'RUL'][i]    
        df_prp = pd.concat([df_prp, join_df])
    df_prp.reset_index(drop=True, inplace=True)

    return df_prp

# %%
# Time tracking, Operation time (min)
t = time.process_time()

# Get h5 filenames 함수
def get_h5_filenames(folder_path):
    h5_filenames = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".h5"):
            h5_filenames.append(filename)
    return h5_filenames

# file derectory의 전체 파일 읽어서 filename 지정
current_dir = os.getcwd()
h5_filenames = get_h5_filenames(current_dir + "/raw_data")
h5_filenames.sort()
file_order = 7
filename = "raw_data/"+h5_filenames[file_order]
filename
# Out:
# 'raw_data/N-CMAPSS_DS08a-009.h5'

# %%
h5_file_list = ['N-CMAPSS_DS01-005.h5','N-CMAPSS_DS02-006.h5','N-CMAPSS_DS03-012.h5',
                'N-CMAPSS_DS04.h5','N-CMAPSS_DS05.h5','N-CMAPSS_DS06.h5',
                'N-CMAPSS_DS07.h5','N-CMAPSS_DS08a-009.h5','N-CMAPSS_DS08c-008.h5']

f_mode_list = ['hpt','hpt+lpt','hpt+lpt','fan','hpc','hpc+lpc','lpt','all','all']

with h5py.File(filename, 'r') as hdf:
        # Development(training) set
        W_dev = np.array(hdf.get('W_dev'))             # W 
        X_s_dev = np.array(hdf.get('X_s_dev'))         # X_s
        X_v_dev = np.array(hdf.get('X_v_dev'))         # X_v
        T_dev = np.array(hdf.get('T_dev'))             # T
        Y_dev = np.array(hdf.get('Y_dev'))             # RUL  
        A_dev = np.array(hdf.get('A_dev'))             # Auxiliary

        # Test set
        W_test = np.array(hdf.get('W_test'))           # W
        X_s_test = np.array(hdf.get('X_s_test'))       # X_s
        X_v_test = np.array(hdf.get('X_v_test'))       # X_v
        T_test = np.array(hdf.get('T_test'))           # T
        Y_test = np.array(hdf.get('Y_test'))           # RUL  
        A_test = np.array(hdf.get('A_test'))           # Auxiliary
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))  
        X_v_var = np.array(hdf.get('X_v_var')) 
        T_var = np.array(hdf.get('T_var'))
        A_var = np.array(hdf.get('A_var'))
        
        # from np.array to list dtype U4/U5
        W_var = list(np.array(W_var, dtype='U20'))
        X_s_var = list(np.array(X_s_var, dtype='U20'))  
        X_v_var = list(np.array(X_v_var, dtype='U20')) 
        T_var = list(np.array(T_var, dtype='U20'))
        A_var = list(np.array(A_var, dtype='U20'))
                          
W = np.concatenate((W_dev, W_test), axis=0)  
X_s = np.concatenate((X_s_dev, X_s_test), axis=0)
X_v = np.concatenate((X_v_dev, X_v_test), axis=0)
T = np.concatenate((T_dev, T_test), axis=0)
Y = np.concatenate((Y_dev, Y_test), axis=0) 
A = np.concatenate((A_dev, A_test), axis=0)

# df _ W, Xs, Y, A
df_W = DataFrame(data=W, columns=W_var)
df_Xs = DataFrame(data=X_s, columns=X_s_var)
df_Xv = DataFrame(data=X_v, columns=X_v_var)
df_T = DataFrame(data=T, columns=T_var)
df_Y = DataFrame(data=Y, columns=['RUL'])
df_A = DataFrame(data=A, columns=A_var)
df_A["failure_mode"] = f_mode_list[file_order]
data_name = filename.split('/')[-1]
data_name = data_name.split('.')[0]
df_A["file_name"] = data_name

df_tmp = pd.concat([df_W, df_Xs, df_Xv, df_T, df_Y, df_A], axis=1)

# %%
# phase feature 추가
df_with_phase = pd.DataFrame(columns=df_tmp.columns)
unit_cycle_list = df_tmp[['unit', 'cycle']].drop_duplicates().reset_index(drop=True)

for i in range(0, unit_cycle_list.shape[0]):
    #진행현황
    print("Processing: "+str(i)+"/"+str(unit_cycle_list.shape[0]))
    data_with_phase = df_tmp.loc[(df_tmp['unit'] == unit_cycle_list['unit'][i])
                                &(df_tmp['cycle'] == unit_cycle_list['cycle'][i])]
    data_with_phase = getPhaseData(data_with_phase)
    cols_to_convert = ['climb', 'cruise', 'descend']
    for col in cols_to_convert:
        data_with_phase[col] = data_with_phase[col].astype(bool)

    df_with_phase = pd.concat((df_with_phase, data_with_phase), axis=0)
    for col in cols_to_convert:
        df_with_phase[col] = df_with_phase[col].astype(bool)

#비행시간 추출
flight_time = pd.DataFrame(df_A.groupby(["unit","cycle"])["Fc"].count()).reset_index()
flight_time["flight_time(min)"] = round(flight_time["Fc"]/60,2)
df_with_phase = df_with_phase.merge(flight_time[["unit","cycle","flight_time(min)"]], 
                                    how = 'left', on = ["unit","cycle"])
# Out:
# Processing: 0/994
# Processing: 1/994
# Processing: 2/994
# Processing: 3/994
# Processing: 4/994
# Processing: 5/994
# Processing: 6/994
# Processing: 7/994
# Processing: 8/994
# Processing: 9/994
# Processing: 10/994
# Processing: 11/994
# Processing: 12/994
# Processing: 13/994
# Processing: 14/994
# Processing: 15/994
# Processing: 16/994
# Processing: 17/994
# Processing: 18/994
# Processing: 19/994
# Processing: 20/994
# Processing: 21/994
# Processing: 22/994
# Processing: 23/994
# Processing: 24/994
# Processing: 25/994
# Processing: 26/994
# Processing: 27/994
# Processing: 28/994
# Processing: 29/994
# Processing: 30/994
# Processing: 31/994
# Processing: 32/994
# Processing: 33/994
# Processing: 34/994
# Processing: 35/994
# Processing: 36/994
# Processing: 37/994
# Processing: 38/994
# Processing: 39/994
# Processing: 40/994
# Processing: 41/994
# Processing: 42/994
# Processing: 43/994
# Processing: 44/994
# Processing: 45/994
# Processing: 46/994
# Processing: 47/994
# Processing: 48/994
# Processing: 49/994
# Processing: 50/994
# Processing: 51/994
# Processing: 52/994
# Processing: 53/994
# Processing: 54/994
# Processing: 55/994
# Processing: 56/994
# Processing: 57/994
# Processing: 58/994
# Processing: 59/994
# Processing: 60/994
# Processing: 61/994
# Processing: 62/994
# Processing: 63/994
# Processing: 64/994
# Processing: 65/994
# Processing: 66/994
# Processing: 67/994
# Processing: 68/994
# Processing: 69/994
# Processing: 70/994
# Processing: 71/994
# Processing: 72/994
# Processing: 73/994
# Processing: 74/994
# Processing: 75/994
# Processing: 76/994
# Processing: 77/994
# Processing: 78/994
# Processing: 79/994
# Processing: 80/994
# Processing: 81/994
# Processing: 82/994
# Processing: 83/994
# Processing: 84/994
# Processing: 85/994
# Processing: 86/994
# Processing: 87/994
# Processing: 88/994
# Processing: 89/994
# Processing: 90/994
# Processing: 91/994
# Processing: 92/994
# Processing: 93/994
# Processing: 94/994
# Processing: 95/994
# Processing: 96/994
# Processing: 97/994
# Processing: 98/994
# Processing: 99/994
# Processing: 100/994
# Processing: 101/994
# Processing: 102/994
# Processing: 103/994
# Processing: 104/994
# Processing: 105/994
# Processing: 106/994
# Processing: 107/994
# Processing: 108/994
# Processing: 109/994
# Processing: 110/994
# Processing: 111/994
# Processing: 112/994
# Processing: 113/994
# Processing: 114/994
# Processing: 115/994
# Processing: 116/994
# Processing: 117/994
# Processing: 118/994
# Processing: 119/994
# Processing: 120/994
# Processing: 121/994
# Processing: 122/994
# Processing: 123/994
# Processing: 124/994
# Processing: 125/994
# Processing: 126/994
# Processing: 127/994
# Processing: 128/994
# Processing: 129/994
# Processing: 130/994
# Processing: 131/994
# Processing: 132/994
# Processing: 133/994
# Processing: 134/994
# Processing: 135/994
# Processing: 136/994
# Processing: 137/994
# Processing: 138/994
# Processing: 139/994
# Processing: 140/994
# Processing: 141/994
# Processing: 142/994
# Processing: 143/994
# Processing: 144/994
# Processing: 145/994
# Processing: 146/994
# Processing: 147/994
# Processing: 148/994
# Processing: 149/994
# Processing: 150/994
# Processing: 151/994
# Processing: 152/994
# Processing: 153/994
# Processing: 154/994
# Processing: 155/994
# Processing: 156/994
# Processing: 157/994
# Processing: 158/994
# Processing: 159/994
# Processing: 160/994
# Processing: 161/994
# Processing: 162/994
# Processing: 163/994
# Processing: 164/994
# Processing: 165/994
# Processing: 166/994
# Processing: 167/994
# Processing: 168/994
# Processing: 169/994
# Processing: 170/994
# Processing: 171/994
# Processing: 172/994
# Processing: 173/994
# Processing: 174/994
# Processing: 175/994
# Processing: 176/994
# Processing: 177/994
# Processing: 178/994
# Processing: 179/994
# Processing: 180/994
# Processing: 181/994
# Processing: 182/994
# Processing: 183/994
# Processing: 184/994
# Processing: 185/994
# Processing: 186/994
# Processing: 187/994
# Processing: 188/994
# Processing: 189/994
# Processing: 190/994
# Processing: 191/994
# Processing: 192/994
# Processing: 193/994
# Processing: 194/994
# Processing: 195/994
# Processing: 196/994
# Processing: 197/994
# Processing: 198/994
# Processing: 199/994
# Processing: 200/994
# Processing: 201/994
# Processing: 202/994
# Processing: 203/994
# Processing: 204/994
# Processing: 205/994
# Processing: 206/994
# Processing: 207/994
# Processing: 208/994
# Processing: 209/994
# Processing: 210/994
# Processing: 211/994
# Processing: 212/994
# Processing: 213/994
# Processing: 214/994
# Processing: 215/994
# Processing: 216/994
# Processing: 217/994
# Processing: 218/994
# Processing: 219/994
# Processing: 220/994
# Processing: 221/994
# Processing: 222/994
# Processing: 223/994
# Processing: 224/994
# Processing: 225/994
# Processing: 226/994
# Processing: 227/994
# Processing: 228/994
# Processing: 229/994
# Processing: 230/994
# Processing: 231/994
# Processing: 232/994
# Processing: 233/994
# Processing: 234/994
# Processing: 235/994
# Processing: 236/994
# Processing: 237/994
# Processing: 238/994
# Processing: 239/994
# Processing: 240/994
# Processing: 241/994
# Processing: 242/994
# Processing: 243/994
# Processing: 244/994
# Processing: 245/994
# Processing: 246/994
# Processing: 247/994
# Processing: 248/994
# Processing: 249/994
# Processing: 250/994
# Processing: 251/994
# Processing: 252/994
# Processing: 253/994
# Processing: 254/994
# Processing: 255/994
# Processing: 256/994
# Processing: 257/994
# Processing: 258/994
# Processing: 259/994
# Processing: 260/994
# Processing: 261/994
# Processing: 262/994
# Processing: 263/994
# Processing: 264/994
# Processing: 265/994
# Processing: 266/994
# Processing: 267/994
# Processing: 268/994
# Processing: 269/994
# Processing: 270/994
# Processing: 271/994
# Processing: 272/994
# Processing: 273/994
# Processing: 274/994
# Processing: 275/994
# Processing: 276/994
# Processing: 277/994
# Processing: 278/994
# Processing: 279/994
# Processing: 280/994
# Processing: 281/994
# Processing: 282/994
# Processing: 283/994
# Processing: 284/994
# Processing: 285/994
# Processing: 286/994
# Processing: 287/994
# Processing: 288/994
# Processing: 289/994
# Processing: 290/994
# Processing: 291/994
# Processing: 292/994
# Processing: 293/994
# Processing: 294/994
# Processing: 295/994
# Processing: 296/994
# Processing: 297/994
# Processing: 298/994
# Processing: 299/994
# Processing: 300/994
# Processing: 301/994
# Processing: 302/994
# Processing: 303/994
# Processing: 304/994
# Processing: 305/994
# Processing: 306/994
# Processing: 307/994
# Processing: 308/994
# Processing: 309/994
# Processing: 310/994
# Processing: 311/994
# Processing: 312/994
# Processing: 313/994
# Processing: 314/994
# Processing: 315/994
# Processing: 316/994
# Processing: 317/994
# Processing: 318/994
# Processing: 319/994
# Processing: 320/994
# Processing: 321/994
# Processing: 322/994
# Processing: 323/994
# Processing: 324/994
# Processing: 325/994
# Processing: 326/994
# Processing: 327/994
# Processing: 328/994
# Processing: 329/994
# Processing: 330/994
# Processing: 331/994
# Processing: 332/994
# Processing: 333/994
# Processing: 334/994
# Processing: 335/994
# Processing: 336/994
# Processing: 337/994
# Processing: 338/994
# Processing: 339/994
# Processing: 340/994
# Processing: 341/994
# Processing: 342/994
# Processing: 343/994
# Processing: 344/994
# Processing: 345/994
# Processing: 346/994
# Processing: 347/994
# Processing: 348/994
# Processing: 349/994
# Processing: 350/994
# Processing: 351/994
# Processing: 352/994
# Processing: 353/994
# Processing: 354/994
# Processing: 355/994
# Processing: 356/994
# Processing: 357/994
# Processing: 358/994
# Processing: 359/994
# Processing: 360/994
# Processing: 361/994
# Processing: 362/994
# Processing: 363/994
# Processing: 364/994
# Processing: 365/994
# Processing: 366/994
# Processing: 367/994
# Processing: 368/994
# Processing: 369/994
# Processing: 370/994
# Processing: 371/994
# Processing: 372/994
# Processing: 373/994
# Processing: 374/994
# Processing: 375/994
# Processing: 376/994
# Processing: 377/994
# Processing: 378/994
# Processing: 379/994
# Processing: 380/994
# Processing: 381/994
# Processing: 382/994
# Processing: 383/994
# Processing: 384/994
# Processing: 385/994
# Processing: 386/994
# Processing: 387/994
# Processing: 388/994
# Processing: 389/994
# Processing: 390/994
# Processing: 391/994
# Processing: 392/994
# Processing: 393/994
# Processing: 394/994
# Processing: 395/994
# Processing: 396/994
# Processing: 397/994
# Processing: 398/994
# Processing: 399/994
# Processing: 400/994
# Processing: 401/994
# Processing: 402/994
# Processing: 403/994
# Processing: 404/994
# Processing: 405/994
# Processing: 406/994
# Processing: 407/994
# Processing: 408/994
# Processing: 409/994
# Processing: 410/994
# Processing: 411/994
# Processing: 412/994
# Processing: 413/994
# Processing: 414/994
# Processing: 415/994
# Processing: 416/994
# Processing: 417/994
# Processing: 418/994
# Processing: 419/994
# Processing: 420/994
# Processing: 421/994
# Processing: 422/994
# Processing: 423/994
# Processing: 424/994
# Processing: 425/994
# Processing: 426/994
# Processing: 427/994
# Processing: 428/994
# Processing: 429/994
# Processing: 430/994
# Processing: 431/994
# Processing: 432/994
# Processing: 433/994
# Processing: 434/994
# Processing: 435/994
# Processing: 436/994
# Processing: 437/994
# Processing: 438/994
# Processing: 439/994
# Processing: 440/994
# Processing: 441/994
# Processing: 442/994
# Processing: 443/994
# Processing: 444/994
# Processing: 445/994
# Processing: 446/994
# Processing: 447/994
# Processing: 448/994
# Processing: 449/994
# Processing: 450/994
# Processing: 451/994
# Processing: 452/994
# Processing: 453/994
# Processing: 454/994
# Processing: 455/994
# Processing: 456/994
# Processing: 457/994
# Processing: 458/994
# Processing: 459/994
# Processing: 460/994
# Processing: 461/994
# Processing: 462/994
# Processing: 463/994
# Processing: 464/994
# Processing: 465/994
# Processing: 466/994
# Processing: 467/994
# Processing: 468/994
# Processing: 469/994
# Processing: 470/994
# Processing: 471/994
# Processing: 472/994
# Processing: 473/994
# Processing: 474/994
# Processing: 475/994
# Processing: 476/994
# Processing: 477/994
# Processing: 478/994
# Processing: 479/994
# Processing: 480/994
# Processing: 481/994
# Processing: 482/994
# Processing: 483/994
# Processing: 484/994
# Processing: 485/994
# Processing: 486/994
# Processing: 487/994
# Processing: 488/994
# Processing: 489/994
# Processing: 490/994
# Processing: 491/994
# Processing: 492/994
# Processing: 493/994
# Processing: 494/994
# Processing: 495/994
# Processing: 496/994
# Processing: 497/994
# Processing: 498/994
# Processing: 499/994
# Processing: 500/994
# Processing: 501/994
# Processing: 502/994
# Processing: 503/994
# Processing: 504/994
# Processing: 505/994
# Processing: 506/994
# Processing: 507/994
# Processing: 508/994
# Processing: 509/994
# Processing: 510/994
# Processing: 511/994
# Processing: 512/994
# Processing: 513/994
# Processing: 514/994
# Processing: 515/994
# Processing: 516/994
# Processing: 517/994
# Processing: 518/994
# Processing: 519/994
# Processing: 520/994
# Processing: 521/994
# Processing: 522/994
# Processing: 523/994
# Processing: 524/994
# Processing: 525/994
# Processing: 526/994
# Processing: 527/994
# Processing: 528/994
# Processing: 529/994
# Processing: 530/994
# Processing: 531/994
# Processing: 532/994
# Processing: 533/994
# Processing: 534/994
# Processing: 535/994
# Processing: 536/994
# Processing: 537/994
# Processing: 538/994
# Processing: 539/994
# Processing: 540/994
# Processing: 541/994
# Processing: 542/994
# Processing: 543/994
# Processing: 544/994
# Processing: 545/994
# Processing: 546/994
# Processing: 547/994
# Processing: 548/994
# Processing: 549/994
# Processing: 550/994
# Processing: 551/994
# Processing: 552/994
# Processing: 553/994
# Processing: 554/994
# Processing: 555/994
# Processing: 556/994
# Processing: 557/994
# Processing: 558/994
# Processing: 559/994
# Processing: 560/994
# Processing: 561/994
# Processing: 562/994
# Processing: 563/994
# Processing: 564/994
# Processing: 565/994
# Processing: 566/994
# Processing: 567/994
# Processing: 568/994
# Processing: 569/994
# Processing: 570/994
# Processing: 571/994
# Processing: 572/994
# Processing: 573/994
# Processing: 574/994
# Processing: 575/994
# Processing: 576/994
# Processing: 577/994
# Processing: 578/994
# Processing: 579/994
# Processing: 580/994
# Processing: 581/994
# Processing: 582/994
# Processing: 583/994
# Processing: 584/994
# Processing: 585/994
# Processing: 586/994
# Processing: 587/994
# Processing: 588/994
# Processing: 589/994
# Processing: 590/994
# Processing: 591/994
# Processing: 592/994
# Processing: 593/994
# Processing: 594/994
# Processing: 595/994
# Processing: 596/994
# Processing: 597/994
# Processing: 598/994
# Processing: 599/994
# Processing: 600/994
# Processing: 601/994
# Processing: 602/994
# Processing: 603/994
# Processing: 604/994
# Processing: 605/994
# Processing: 606/994
# Processing: 607/994
# Processing: 608/994
# Processing: 609/994
# Processing: 610/994
# Processing: 611/994
# Processing: 612/994
# Processing: 613/994
# Processing: 614/994
# Processing: 615/994
# Processing: 616/994
# Processing: 617/994
# Processing: 618/994
# Processing: 619/994
# Processing: 620/994
# Processing: 621/994
# Processing: 622/994
# Processing: 623/994
# Processing: 624/994
# Processing: 625/994
# Processing: 626/994
# Processing: 627/994
# Processing: 628/994
# Processing: 629/994
# Processing: 630/994
# Processing: 631/994
# Processing: 632/994
# Processing: 633/994
# Processing: 634/994
# Processing: 635/994
# Processing: 636/994
# Processing: 637/994
# Processing: 638/994
# Processing: 639/994
# Processing: 640/994
# Processing: 641/994
# Processing: 642/994
# Processing: 643/994
# Processing: 644/994
# Processing: 645/994
# Processing: 646/994
# Processing: 647/994
# Processing: 648/994
# Processing: 649/994
# Processing: 650/994
# Processing: 651/994
# Processing: 652/994
# Processing: 653/994
# Processing: 654/994
# Processing: 655/994
# Processing: 656/994
# Processing: 657/994
# Processing: 658/994
# Processing: 659/994
# Processing: 660/994
# Processing: 661/994
# Processing: 662/994
# Processing: 663/994
# Processing: 664/994
# Processing: 665/994
# Processing: 666/994
# Processing: 667/994
# Processing: 668/994
# Processing: 669/994
# Processing: 670/994
# Processing: 671/994
# Processing: 672/994
# Processing: 673/994
# Processing: 674/994
# Processing: 675/994
# Processing: 676/994
# Processing: 677/994
# Processing: 678/994
# Processing: 679/994
# Processing: 680/994
# Processing: 681/994
# Processing: 682/994
# Processing: 683/994
# Processing: 684/994
# Processing: 685/994
# Processing: 686/994
# Processing: 687/994
# Processing: 688/994
# Processing: 689/994
# Processing: 690/994
# Processing: 691/994
# Processing: 692/994
# Processing: 693/994
# Processing: 694/994
# Processing: 695/994
# Processing: 696/994
# Processing: 697/994
# Processing: 698/994
# Processing: 699/994
# Processing: 700/994
# Processing: 701/994
# Processing: 702/994
# Processing: 703/994
# Processing: 704/994
# Processing: 705/994
# Processing: 706/994
# Processing: 707/994
# Processing: 708/994
# Processing: 709/994
# Processing: 710/994
# Processing: 711/994
# Processing: 712/994
# Processing: 713/994
# Processing: 714/994
# Processing: 715/994
# Processing: 716/994
# Processing: 717/994
# Processing: 718/994
# Processing: 719/994
# Processing: 720/994
# Processing: 721/994
# Processing: 722/994
# Processing: 723/994
# Processing: 724/994
# Processing: 725/994
# Processing: 726/994
# Processing: 727/994
# Processing: 728/994
# Processing: 729/994
# Processing: 730/994
# Processing: 731/994
# Processing: 732/994
# Processing: 733/994
# Processing: 734/994
# Processing: 735/994
# Processing: 736/994
# Processing: 737/994
# Processing: 738/994
# Processing: 739/994
# Processing: 740/994
# Processing: 741/994
# Processing: 742/994
# Processing: 743/994
# Processing: 744/994
# Processing: 745/994
# Processing: 746/994
# Processing: 747/994
# Processing: 748/994
# Processing: 749/994
# Processing: 750/994
# Processing: 751/994
# Processing: 752/994
# Processing: 753/994
# Processing: 754/994
# Processing: 755/994
# Processing: 756/994
# Processing: 757/994
# Processing: 758/994
# Processing: 759/994
# Processing: 760/994
# Processing: 761/994
# Processing: 762/994
# Processing: 763/994
# Processing: 764/994
# Processing: 765/994
# Processing: 766/994
# Processing: 767/994
# Processing: 768/994
# Processing: 769/994
# Processing: 770/994
# Processing: 771/994
# Processing: 772/994
# Processing: 773/994
# Processing: 774/994
# Processing: 775/994
# Processing: 776/994
# Processing: 777/994
# Processing: 778/994
# Processing: 779/994
# Processing: 780/994
# Processing: 781/994
# Processing: 782/994
# Processing: 783/994
# Processing: 784/994
# Processing: 785/994
# Processing: 786/994
# Processing: 787/994
# Processing: 788/994
# Processing: 789/994
# Processing: 790/994
# Processing: 791/994
# Processing: 792/994
# Processing: 793/994
# Processing: 794/994
# Processing: 795/994
# Processing: 796/994
# Processing: 797/994
# Processing: 798/994
# Processing: 799/994
# Processing: 800/994
# Processing: 801/994
# Processing: 802/994
# Processing: 803/994
# Processing: 804/994
# Processing: 805/994
# Processing: 806/994
# Processing: 807/994
# Processing: 808/994
# Processing: 809/994
# Processing: 810/994
# Processing: 811/994
# Processing: 812/994
# Processing: 813/994
# Processing: 814/994
# Processing: 815/994
# Processing: 816/994
# Processing: 817/994
# Processing: 818/994
# Processing: 819/994
# Processing: 820/994
# Processing: 821/994
# Processing: 822/994
# Processing: 823/994
# Processing: 824/994
# Processing: 825/994
# Processing: 826/994
# Processing: 827/994
# Processing: 828/994
# Processing: 829/994
# Processing: 830/994
# Processing: 831/994
# Processing: 832/994
# Processing: 833/994
# Processing: 834/994
# Processing: 835/994
# Processing: 836/994
# Processing: 837/994
# Processing: 838/994
# Processing: 839/994
# Processing: 840/994
# Processing: 841/994
# Processing: 842/994
# Processing: 843/994
# Processing: 844/994
# Processing: 845/994
# Processing: 846/994
# Processing: 847/994
# Processing: 848/994
# Processing: 849/994
# Processing: 850/994
# Processing: 851/994
# Processing: 852/994
# Processing: 853/994
# Processing: 854/994
# Processing: 855/994
# Processing: 856/994
# Processing: 857/994
# Processing: 858/994
# Processing: 859/994
# Processing: 860/994
# Processing: 861/994
# Processing: 862/994
# Processing: 863/994
# Processing: 864/994
# Processing: 865/994
# Processing: 866/994
# Processing: 867/994
# Processing: 868/994
# Processing: 869/994
# Processing: 870/994
# Processing: 871/994
# Processing: 872/994
# Processing: 873/994
# Processing: 874/994
# Processing: 875/994
# Processing: 876/994
# Processing: 877/994
# Processing: 878/994
# Processing: 879/994
# Processing: 880/994
# Processing: 881/994
# Processing: 882/994
# Processing: 883/994
# Processing: 884/994
# Processing: 885/994
# Processing: 886/994
# Processing: 887/994
# Processing: 888/994
# Processing: 889/994
# Processing: 890/994
# Processing: 891/994
# Processing: 892/994
# Processing: 893/994
# Processing: 894/994
# Processing: 895/994
# Processing: 896/994
# Processing: 897/994
# Processing: 898/994
# Processing: 899/994
# Processing: 900/994
# Processing: 901/994
# Processing: 902/994
# Processing: 903/994
# Processing: 904/994
# Processing: 905/994
# Processing: 906/994
# Processing: 907/994
# Processing: 908/994
# Processing: 909/994
# Processing: 910/994
# Processing: 911/994
# Processing: 912/994
# Processing: 913/994
# Processing: 914/994
# Processing: 915/994
# Processing: 916/994
# Processing: 917/994
# Processing: 918/994
# Processing: 919/994
# Processing: 920/994
# Processing: 921/994
# Processing: 922/994
# Processing: 923/994
# Processing: 924/994
# Processing: 925/994
# Processing: 926/994
# Processing: 927/994
# Processing: 928/994
# Processing: 929/994
# Processing: 930/994
# Processing: 931/994
# Processing: 932/994
# Processing: 933/994
# Processing: 934/994
# Processing: 935/994
# Processing: 936/994
# Processing: 937/994
# Processing: 938/994
# Processing: 939/994
# Processing: 940/994
# Processing: 941/994
# Processing: 942/994
# Processing: 943/994
# Processing: 944/994
# Processing: 945/994
# Processing: 946/994
# Processing: 947/994
# Processing: 948/994
# Processing: 949/994
# Processing: 950/994
# Processing: 951/994
# Processing: 952/994
# Processing: 953/994
# Processing: 954/994
# Processing: 955/994
# Processing: 956/994
# Processing: 957/994
# Processing: 958/994
# Processing: 959/994
# Processing: 960/994
# Processing: 961/994
# Processing: 962/994
# Processing: 963/994
# Processing: 964/994
# Processing: 965/994
# Processing: 966/994
# Processing: 967/994
# Processing: 968/994
# Processing: 969/994
# Processing: 970/994
# Processing: 971/994
# Processing: 972/994
# Processing: 973/994
# Processing: 974/994
# Processing: 975/994
# Processing: 976/994
# Processing: 977/994
# Processing: 978/994
# Processing: 979/994
# Processing: 980/994
# Processing: 981/994
# Processing: 982/994
# Processing: 983/994
# Processing: 984/994
# Processing: 985/994
# Processing: 986/994
# Processing: 987/994
# Processing: 988/994
# Processing: 989/994
# Processing: 990/994
# Processing: 991/994
# Processing: 992/994
# Processing: 993/994

# %%
# 파생 변수 추가
df_with_phase_add_var = gen_additional_var(df_with_phase)
# health label 추가
df_with_phase_add_var_label = label_data(df_with_phase)
df_PVL = df_with_phase_add_var_label.copy()
# fileNo, Fc 추가
df_PVL['fileNo'] = file_order

df_all = df_PVL.copy()


del(df_tmp)
del(df_with_phase)
del(df_with_phase_add_var)
del(df_with_phase_add_var_label)

df_PVL.drop(["tartget","failure_mode"],axis=1, inplace= True)

# df_cruise / df_climb 나눔(컬럼명도 재조정)
df_climb = df_PVL.loc[df_PVL['climb'] == True].copy()
df_climb.columns = 'climb_' + df_PVL.columns
df_cruise = df_PVL.loc[df_PVL['cruise'] == True].copy()
df_cruise.columns = 'cruise_' + df_PVL.columns

# use 컬럼 준비
W_var = ['alt', 'Mach', 'TRA', 'T2']
xs_var = ['T24', 'T30', 'T48', 'T50', 'P15', 'P2', 'P21', 'P24', 'Ps30', 'P40', 'P50', 'Nf', 'Nc', 'Wf']
X_v_var = ['T40', 'P30', 'P45', 'W21', 'W22', 'W25', 'W31', 'W32', 'W48', 'W50', 'SmFan', 'SmLPC', 'SmHPC', 'phi']
T_var = ['fan_eff_mod', 'fan_flow_mod', 'LPC_eff_mod', 'LPC_flow_mod', 'HPC_eff_mod', 'HPC_flow_mod', 'HPT_eff_mod', 'HPT_flow_mod', 'LPT_eff_mod', 'LPT_flow_mod']
A_var = ['RUL','unit', 'cycle', 'Fc', 'hs']
new_var = ['hpc_lpc_temp', 'hpt_hpc_temp', 'lpt_hpt_temp', 
           'lpc_fan_press', 'hpc_lpc_press', 'hpt_hpc_press', 'lpt_hpt_press', 
           'hpc_lpc_temp_ratio', 'hpt_hpc_temp_ratio', 'lpt_hpt_temp_ratio', 'lpc_fan_press_ratio', 
           'hpc_lpc_press_ratio', 'hpt_hpc_press_ratio', 'lpt_hpt_press_ratio', 'hpt_entry_temp_drop', 
           'lpt_entry_temp_drop', 'hpt_entry_press_ratio', 'fan_exit_press', 'hpc_exit_press', 'hpc_entry_temp']
use_columns = W_var + xs_var + X_v_var + new_var

# use 컬럼에 climb_ cruise_ 붙이기
climb_use_columns = use_columns.copy()  
cruise_use_columns = use_columns.copy()
word = 'climb_'
word2 = 'cruise_'
for i in range(0,len(use_columns)):
    climb_use_columns[i] = word+use_columns[i]
    cruise_use_columns[i] = word2+use_columns[i]

# Climb 데이터 생성
df_prp_climb = data_prp(df_climb,climb_use_columns,'climb_')
df_prp_climb.to_csv(f"df_prp_climb_{file_order}.csv")

# Cruise 데이터 생성
df_prp_cruise = data_prp(df_cruise, cruise_use_columns, 'cruise_')
df_prp_cruise.to_csv(f"df_prp_cruise_{file_order}.csv")

# 데이터 결합
df_prp_cruise = df_prp_cruise.drop(['cruise_flight_time(min)','cruise_unit','cruise_cycle','cruise_Fc','cruise_fileNo',
                                    'cruise_hpt_yn','cruise_lpt_yn','cruise_fan_yn',
                                    'cruise_hpc_yn','cruise_lpc_yn','cruise_RUL'],axis=1)
df_prp_f = pd.concat((df_prp_cruise, df_prp_climb), axis=1 )

# 컬럼명 변경
df_prp_f.rename(columns = {'climb_flight_time(min)':'flight_time(min)','climb_unit':'unit','climb_Fc':'Fc','climb_fileNo':'fileNo'
                           ,'climb_cycle':'cycle','climb_hpt_yn':'hpt_yn'
                           ,'climb_lpt_yn':'lpt_yn','climb_fan_yn':'fan_yn'
                           ,'climb_hpc_yn':'hpc_yn','climb_lpc_yn':'lpc_yn'
                           ,'climb_rul':'rul'},inplace=True)

# 1개 사이클이전, 부품건강상태
df_prp_f['hpt_yn_shift1'] = df_prp_f['hpt_yn'].shift(1)
df_prp_f['lpt_yn_shift1'] = df_prp_f['lpt_yn'].shift(1)
df_prp_f['fan_yn_shift1'] = df_prp_f['fan_yn'].shift(1)
df_prp_f['hpc_yn_shift1'] = df_prp_f['hpc_yn'].shift(1)
df_prp_f['lpc_yn_shift1'] = df_prp_f['lpc_yn'].shift(1)
df_prp_f.fillna(0, inplace=True)
df_prp_f['hpt_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
df_prp_f['lpt_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
df_prp_f['fan_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
df_prp_f['hpc_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
df_prp_f['lpc_yn_shift1'].loc[df_prp_f['cycle']==1] = 0

df_prp_f.to_csv(f"df_prp_f_{file_order}.csv")

del(df_prp_f)
del(df_PVL)
del(df_all)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 2)] =  'hpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 5)] =  'hpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 10)] = 'hpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 16)] = 'hpt+lpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 18)] = 'hpt+lpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['failure_mode'].loc[(df['file_name'] == 'N-CMAPSS_DS02-006') & (df['unit'] == 20)] = 'hpt+lpt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tartget'].loc[df['hs'] == 1] = 'healthy'
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hpt_yn'].loc[(df['tartget'] == 'hpt') | (df['tartget'] == 'hpt+lpt') | (df['tartget'] == 'all')] = 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lpt_yn'].loc[(df['tartget'] == 'lpt') | (df['tartget'] == 'hpt+lpt') | (df['tartget'] == 'all')] = 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fan_yn'].loc[(df['tartget'] == 'fan') | (df['tartget'] == 'all')] = 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hpc_yn'].loc[(df['tartget'] == 'hpc') | (df['tartget'] == 'hpc+lpc') | (df['tartget'] == 'all')] = 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\1730928072.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lpc_yn'].loc[(df['tartget'] == 'hpc+lpc') | (df['tartget'] == 'all')] = 1
# 0/994
# 1/994
# 2/994
# 3/994
# 4/994
# 5/994
# 6/994
# 7/994
# 8/994
# 9/994
# 10/994
# 11/994
# 12/994
# 13/994
# 14/994
# 15/994
# 16/994
# 17/994
# 18/994
# 19/994
# 20/994
# 21/994
# 22/994
# 23/994
# 24/994
# 25/994
# 26/994
# 27/994
# 28/994
# 29/994
# 30/994
# 31/994
# 32/994
# 33/994
# 34/994
# 35/994
# 36/994
# 37/994
# 38/994
# 39/994
# 40/994
# 41/994
# 42/994
# 43/994
# 44/994
# 45/994
# 46/994
# 47/994
# 48/994
# 49/994
# 50/994
# 51/994
# 52/994
# 53/994
# 54/994
# 55/994
# 56/994
# 57/994
# 58/994
# 59/994
# 60/994
# 61/994
# 62/994
# 63/994
# 64/994
# 65/994
# 66/994
# 67/994
# 68/994
# 69/994
# 70/994
# 71/994
# 72/994
# 73/994
# 74/994
# 75/994
# 76/994
# 77/994
# 78/994
# 79/994
# 80/994
# 81/994
# 82/994
# 83/994
# 84/994
# 85/994
# 86/994
# 87/994
# 88/994
# 89/994
# 90/994
# 91/994
# 92/994
# 93/994
# 94/994
# 95/994
# 96/994
# 97/994
# 98/994
# 99/994
# 100/994
# 101/994
# 102/994
# 103/994
# 104/994
# 105/994
# 106/994
# 107/994
# 108/994
# 109/994
# 110/994
# 111/994
# 112/994
# 113/994
# 114/994
# 115/994
# 116/994
# 117/994
# 118/994
# 119/994
# 120/994
# 121/994
# 122/994
# 123/994
# 124/994
# 125/994
# 126/994
# 127/994
# 128/994
# 129/994
# 130/994
# 131/994
# 132/994
# 133/994
# 134/994
# 135/994
# 136/994
# 137/994
# 138/994
# 139/994
# 140/994
# 141/994
# 142/994
# 143/994
# 144/994
# 145/994
# 146/994
# 147/994
# 148/994
# 149/994
# 150/994
# 151/994
# 152/994
# 153/994
# 154/994
# 155/994
# 156/994
# 157/994
# 158/994
# 159/994
# 160/994
# 161/994
# 162/994
# 163/994
# 164/994
# 165/994
# 166/994
# 167/994
# 168/994
# 169/994
# 170/994
# 171/994
# 172/994
# 173/994
# 174/994
# 175/994
# 176/994
# 177/994
# 178/994
# 179/994
# 180/994
# 181/994
# 182/994
# 183/994
# 184/994
# 185/994
# 186/994
# 187/994
# 188/994
# 189/994
# 190/994
# 191/994
# 192/994
# 193/994
# 194/994
# 195/994
# 196/994
# 197/994
# 198/994
# 199/994
# 200/994
# 201/994
# 202/994
# 203/994
# 204/994
# 205/994
# 206/994
# 207/994
# 208/994
# 209/994
# 210/994
# 211/994
# 212/994
# 213/994
# 214/994
# 215/994
# 216/994
# 217/994
# 218/994
# 219/994
# 220/994
# 221/994
# 222/994
# 223/994
# 224/994
# 225/994
# 226/994
# 227/994
# 228/994
# 229/994
# 230/994
# 231/994
# 232/994
# 233/994
# 234/994
# 235/994
# 236/994
# 237/994
# 238/994
# 239/994
# 240/994
# 241/994
# 242/994
# 243/994
# 244/994
# 245/994
# 246/994
# 247/994
# 248/994
# 249/994
# 250/994
# 251/994
# 252/994
# 253/994
# 254/994
# 255/994
# 256/994
# 257/994
# 258/994
# 259/994
# 260/994
# 261/994
# 262/994
# 263/994
# 264/994
# 265/994
# 266/994
# 267/994
# 268/994
# 269/994
# 270/994
# 271/994
# 272/994
# 273/994
# 274/994
# 275/994
# 276/994
# 277/994
# 278/994
# 279/994
# 280/994
# 281/994
# 282/994
# 283/994
# 284/994
# 285/994
# 286/994
# 287/994
# 288/994
# 289/994
# 290/994
# 291/994
# 292/994
# 293/994
# 294/994
# 295/994
# 296/994
# 297/994
# 298/994
# 299/994
# 300/994
# 301/994
# 302/994
# 303/994
# 304/994
# 305/994
# 306/994
# 307/994
# 308/994
# 309/994
# 310/994
# 311/994
# 312/994
# 313/994
# 314/994
# 315/994
# 316/994
# 317/994
# 318/994
# 319/994
# 320/994
# 321/994
# 322/994
# 323/994
# 324/994
# 325/994
# 326/994
# 327/994
# 328/994
# 329/994
# 330/994
# 331/994
# 332/994
# 333/994
# 334/994
# 335/994
# 336/994
# 337/994
# 338/994
# 339/994
# 340/994
# 341/994
# 342/994
# 343/994
# 344/994
# 345/994
# 346/994
# 347/994
# 348/994
# 349/994
# 350/994
# 351/994
# 352/994
# 353/994
# 354/994
# 355/994
# 356/994
# 357/994
# 358/994
# 359/994
# 360/994
# 361/994
# 362/994
# 363/994
# 364/994
# 365/994
# 366/994
# 367/994
# 368/994
# 369/994
# 370/994
# 371/994
# 372/994
# 373/994
# 374/994
# 375/994
# 376/994
# 377/994
# 378/994
# 379/994
# 380/994
# 381/994
# 382/994
# 383/994
# 384/994
# 385/994
# 386/994
# 387/994
# 388/994
# 389/994
# 390/994
# 391/994
# 392/994
# 393/994
# 394/994
# 395/994
# 396/994
# 397/994
# 398/994
# 399/994
# 400/994
# 401/994
# 402/994
# 403/994
# 404/994
# 405/994
# 406/994
# 407/994
# 408/994
# 409/994
# 410/994
# 411/994
# 412/994
# 413/994
# 414/994
# 415/994
# 416/994
# 417/994
# 418/994
# 419/994
# 420/994
# 421/994
# 422/994
# 423/994
# 424/994
# 425/994
# 426/994
# 427/994
# 428/994
# 429/994
# 430/994
# 431/994
# 432/994
# 433/994
# 434/994
# 435/994
# 436/994
# 437/994
# 438/994
# 439/994
# 440/994
# 441/994
# 442/994
# 443/994
# 444/994
# 445/994
# 446/994
# 447/994
# 448/994
# 449/994
# 450/994
# 451/994
# 452/994
# 453/994
# 454/994
# 455/994
# 456/994
# 457/994
# 458/994
# 459/994
# 460/994
# 461/994
# 462/994
# 463/994
# 464/994
# 465/994
# 466/994
# 467/994
# 468/994
# 469/994
# 470/994
# 471/994
# 472/994
# 473/994
# 474/994
# 475/994
# 476/994
# 477/994
# 478/994
# 479/994
# 480/994
# 481/994
# 482/994
# 483/994
# 484/994
# 485/994
# 486/994
# 487/994
# 488/994
# 489/994
# 490/994
# 491/994
# 492/994
# 493/994
# 494/994
# 495/994
# 496/994
# 497/994
# 498/994
# 499/994
# 500/994
# 501/994
# 502/994
# 503/994
# 504/994
# 505/994
# 506/994
# 507/994
# 508/994
# 509/994
# 510/994
# 511/994
# 512/994
# 513/994
# 514/994
# 515/994
# 516/994
# 517/994
# 518/994
# 519/994
# 520/994
# 521/994
# 522/994
# 523/994
# 524/994
# 525/994
# 526/994
# 527/994
# 528/994
# 529/994
# 530/994
# 531/994
# 532/994
# 533/994
# 534/994
# 535/994
# 536/994
# 537/994
# 538/994
# 539/994
# 540/994
# 541/994
# 542/994
# 543/994
# 544/994
# 545/994
# 546/994
# 547/994
# 548/994
# 549/994
# 550/994
# 551/994
# 552/994
# 553/994
# 554/994
# 555/994
# 556/994
# 557/994
# 558/994
# 559/994
# 560/994
# 561/994
# 562/994
# 563/994
# 564/994
# 565/994
# 566/994
# 567/994
# 568/994
# 569/994
# 570/994
# 571/994
# 572/994
# 573/994
# 574/994
# 575/994
# 576/994
# 577/994
# 578/994
# 579/994
# 580/994
# 581/994
# 582/994
# 583/994
# 584/994
# 585/994
# 586/994
# 587/994
# 588/994
# 589/994
# 590/994
# 591/994
# 592/994
# 593/994
# 594/994
# 595/994
# 596/994
# 597/994
# 598/994
# 599/994
# 600/994
# 601/994
# 602/994
# 603/994
# 604/994
# 605/994
# 606/994
# 607/994
# 608/994
# 609/994
# 610/994
# 611/994
# 612/994
# 613/994
# 614/994
# 615/994
# 616/994
# 617/994
# 618/994
# 619/994
# 620/994
# 621/994
# 622/994
# 623/994
# 624/994
# 625/994
# 626/994
# 627/994
# 628/994
# 629/994
# 630/994
# 631/994
# 632/994
# 633/994
# 634/994
# 635/994
# 636/994
# 637/994
# 638/994
# 639/994
# 640/994
# 641/994
# 642/994
# 643/994
# 644/994
# 645/994
# 646/994
# 647/994
# 648/994
# 649/994
# 650/994
# 651/994
# 652/994
# 653/994
# 654/994
# 655/994
# 656/994
# 657/994
# 658/994
# 659/994
# 660/994
# 661/994
# 662/994
# 663/994
# 664/994
# 665/994
# 666/994
# 667/994
# 668/994
# 669/994
# 670/994
# 671/994
# 672/994
# 673/994
# 674/994
# 675/994
# 676/994
# 677/994
# 678/994
# 679/994
# 680/994
# 681/994
# 682/994
# 683/994
# 684/994
# 685/994
# 686/994
# 687/994
# 688/994
# 689/994
# 690/994
# 691/994
# 692/994
# 693/994
# 694/994
# 695/994
# 696/994
# 697/994
# 698/994
# 699/994
# 700/994
# 701/994
# 702/994
# 703/994
# 704/994
# 705/994
# 706/994
# 707/994
# 708/994
# 709/994
# 710/994
# 711/994
# 712/994
# 713/994
# 714/994
# 715/994
# 716/994
# 717/994
# 718/994
# 719/994
# 720/994
# 721/994
# 722/994
# 723/994
# 724/994
# 725/994
# 726/994
# 727/994
# 728/994
# 729/994
# 730/994
# 731/994
# 732/994
# 733/994
# 734/994
# 735/994
# 736/994
# 737/994
# 738/994
# 739/994
# 740/994
# 741/994
# 742/994
# 743/994
# 744/994
# 745/994
# 746/994
# 747/994
# 748/994
# 749/994
# 750/994
# 751/994
# 752/994
# 753/994
# 754/994
# 755/994
# 756/994
# 757/994
# 758/994
# 759/994
# 760/994
# 761/994
# 762/994
# 763/994
# 764/994
# 765/994
# 766/994
# 767/994
# 768/994
# 769/994
# 770/994
# 771/994
# 772/994
# 773/994
# 774/994
# 775/994
# 776/994
# 777/994
# 778/994
# 779/994
# 780/994
# 781/994
# 782/994
# 783/994
# 784/994
# 785/994
# 786/994
# 787/994
# 788/994
# 789/994
# 790/994
# 791/994
# 792/994
# 793/994
# 794/994
# 795/994
# 796/994
# 797/994
# 798/994
# 799/994
# 800/994
# 801/994
# 802/994
# 803/994
# 804/994
# 805/994
# 806/994
# 807/994
# 808/994
# 809/994
# 810/994
# 811/994
# 812/994
# 813/994
# 814/994
# 815/994
# 816/994
# 817/994
# 818/994
# 819/994
# 820/994
# 821/994
# 822/994
# 823/994
# 824/994
# 825/994
# 826/994
# 827/994
# 828/994
# 829/994
# 830/994
# 831/994
# 832/994
# 833/994
# 834/994
# 835/994
# 836/994
# 837/994
# 838/994
# 839/994
# 840/994
# 841/994
# 842/994
# 843/994
# 844/994
# 845/994
# 846/994
# 847/994
# 848/994
# 849/994
# 850/994
# 851/994
# 852/994
# 853/994
# 854/994
# 855/994
# 856/994
# 857/994
# 858/994
# 859/994
# 860/994
# 861/994
# 862/994
# 863/994
# 864/994
# 865/994
# 866/994
# 867/994
# 868/994
# 869/994
# 870/994
# 871/994
# 872/994
# 873/994
# 874/994
# 875/994
# 876/994
# 877/994
# 878/994
# 879/994
# 880/994
# 881/994
# 882/994
# 883/994
# 884/994
# 885/994
# 886/994
# 887/994
# 888/994
# 889/994
# 890/994
# 891/994
# 892/994
# 893/994
# 894/994
# 895/994
# 896/994
# 897/994
# 898/994
# 899/994
# 900/994
# 901/994
# 902/994
# 903/994
# 904/994
# 905/994
# 906/994
# 907/994
# 908/994
# 909/994
# 910/994
# 911/994
# 912/994
# 913/994
# 914/994
# 915/994
# 916/994
# 917/994
# 918/994
# 919/994
# 920/994
# 921/994
# 922/994
# 923/994
# 924/994
# 925/994
# 926/994
# 927/994
# 928/994
# 929/994
# 930/994
# 931/994
# 932/994
# 933/994
# 934/994
# 935/994
# 936/994
# 937/994
# 938/994
# 939/994
# 940/994
# 941/994
# 942/994
# 943/994
# 944/994
# 945/994
# 946/994
# 947/994
# 948/994
# 949/994
# 950/994
# 951/994
# 952/994
# 953/994
# 954/994
# 955/994
# 956/994
# 957/994
# 958/994
# 959/994
# 960/994
# 961/994
# 962/994
# 963/994
# 964/994
# 965/994
# 966/994
# 967/994
# 968/994
# 969/994
# 970/994
# 971/994
# 972/994
# 973/994
# 974/994
# 975/994
# 976/994
# 977/994
# 978/994
# 979/994
# 980/994
# 981/994
# 982/994
# 983/994
# 984/994
# 985/994
# 986/994
# 987/994
# 988/994
# 989/994
# 990/994
# 991/994
# 992/994
# 993/994
# 0/994
# 1/994
# 2/994
# 3/994
# 4/994
# 5/994
# 6/994
# 7/994
# 8/994
# 9/994
# 10/994
# 11/994
# 12/994
# 13/994
# 14/994
# 15/994
# 16/994
# 17/994
# 18/994
# 19/994
# 20/994
# 21/994
# 22/994
# 23/994
# 24/994
# 25/994
# 26/994
# 27/994
# 28/994
# 29/994
# 30/994
# 31/994
# 32/994
# 33/994
# 34/994
# 35/994
# 36/994
# 37/994
# 38/994
# 39/994
# 40/994
# 41/994
# 42/994
# 43/994
# 44/994
# 45/994
# 46/994
# 47/994
# 48/994
# 49/994
# 50/994
# 51/994
# 52/994
# 53/994
# 54/994
# 55/994
# 56/994
# 57/994
# 58/994
# 59/994
# 60/994
# 61/994
# 62/994
# 63/994
# 64/994
# 65/994
# 66/994
# 67/994
# 68/994
# 69/994
# 70/994
# 71/994
# 72/994
# 73/994
# 74/994
# 75/994
# 76/994
# 77/994
# 78/994
# 79/994
# 80/994
# 81/994
# 82/994
# 83/994
# 84/994
# 85/994
# 86/994
# 87/994
# 88/994
# 89/994
# 90/994
# 91/994
# 92/994
# 93/994
# 94/994
# 95/994
# 96/994
# 97/994
# 98/994
# 99/994
# 100/994
# 101/994
# 102/994
# 103/994
# 104/994
# 105/994
# 106/994
# 107/994
# 108/994
# 109/994
# 110/994
# 111/994
# 112/994
# 113/994
# 114/994
# 115/994
# 116/994
# 117/994
# 118/994
# 119/994
# 120/994
# 121/994
# 122/994
# 123/994
# 124/994
# 125/994
# 126/994
# 127/994
# 128/994
# 129/994
# 130/994
# 131/994
# 132/994
# 133/994
# 134/994
# 135/994
# 136/994
# 137/994
# 138/994
# 139/994
# 140/994
# 141/994
# 142/994
# 143/994
# 144/994
# 145/994
# 146/994
# 147/994
# 148/994
# 149/994
# 150/994
# 151/994
# 152/994
# 153/994
# 154/994
# 155/994
# 156/994
# 157/994
# 158/994
# 159/994
# 160/994
# 161/994
# 162/994
# 163/994
# 164/994
# 165/994
# 166/994
# 167/994
# 168/994
# 169/994
# 170/994
# 171/994
# 172/994
# 173/994
# 174/994
# 175/994
# 176/994
# 177/994
# 178/994
# 179/994
# 180/994
# 181/994
# 182/994
# 183/994
# 184/994
# 185/994
# 186/994
# 187/994
# 188/994
# 189/994
# 190/994
# 191/994
# 192/994
# 193/994
# 194/994
# 195/994
# 196/994
# 197/994
# 198/994
# 199/994
# 200/994
# 201/994
# 202/994
# 203/994
# 204/994
# 205/994
# 206/994
# 207/994
# 208/994
# 209/994
# 210/994
# 211/994
# 212/994
# 213/994
# 214/994
# 215/994
# 216/994
# 217/994
# 218/994
# 219/994
# 220/994
# 221/994
# 222/994
# 223/994
# 224/994
# 225/994
# 226/994
# 227/994
# 228/994
# 229/994
# 230/994
# 231/994
# 232/994
# 233/994
# 234/994
# 235/994
# 236/994
# 237/994
# 238/994
# 239/994
# 240/994
# 241/994
# 242/994
# 243/994
# 244/994
# 245/994
# 246/994
# 247/994
# 248/994
# 249/994
# 250/994
# 251/994
# 252/994
# 253/994
# 254/994
# 255/994
# 256/994
# 257/994
# 258/994
# 259/994
# 260/994
# 261/994
# 262/994
# 263/994
# 264/994
# 265/994
# 266/994
# 267/994
# 268/994
# 269/994
# 270/994
# 271/994
# 272/994
# 273/994
# 274/994
# 275/994
# 276/994
# 277/994
# 278/994
# 279/994
# 280/994
# 281/994
# 282/994
# 283/994
# 284/994
# 285/994
# 286/994
# 287/994
# 288/994
# 289/994
# 290/994
# 291/994
# 292/994
# 293/994
# 294/994
# 295/994
# 296/994
# 297/994
# 298/994
# 299/994
# 300/994
# 301/994
# 302/994
# 303/994
# 304/994
# 305/994
# 306/994
# 307/994
# 308/994
# 309/994
# 310/994
# 311/994
# 312/994
# 313/994
# 314/994
# 315/994
# 316/994
# 317/994
# 318/994
# 319/994
# 320/994
# 321/994
# 322/994
# 323/994
# 324/994
# 325/994
# 326/994
# 327/994
# 328/994
# 329/994
# 330/994
# 331/994
# 332/994
# 333/994
# 334/994
# 335/994
# 336/994
# 337/994
# 338/994
# 339/994
# 340/994
# 341/994
# 342/994
# 343/994
# 344/994
# 345/994
# 346/994
# 347/994
# 348/994
# 349/994
# 350/994
# 351/994
# 352/994
# 353/994
# 354/994
# 355/994
# 356/994
# 357/994
# 358/994
# 359/994
# 360/994
# 361/994
# 362/994
# 363/994
# 364/994
# 365/994
# 366/994
# 367/994
# 368/994
# 369/994
# 370/994
# 371/994
# 372/994
# 373/994
# 374/994
# 375/994
# 376/994
# 377/994
# 378/994
# 379/994
# 380/994
# 381/994
# 382/994
# 383/994
# 384/994
# 385/994
# 386/994
# 387/994
# 388/994
# 389/994
# 390/994
# 391/994
# 392/994
# 393/994
# 394/994
# 395/994
# 396/994
# 397/994
# 398/994
# 399/994
# 400/994
# 401/994
# 402/994
# 403/994
# 404/994
# 405/994
# 406/994
# 407/994
# 408/994
# 409/994
# 410/994
# 411/994
# 412/994
# 413/994
# 414/994
# 415/994
# 416/994
# 417/994
# 418/994
# 419/994
# 420/994
# 421/994
# 422/994
# 423/994
# 424/994
# 425/994
# 426/994
# 427/994
# 428/994
# 429/994
# 430/994
# 431/994
# 432/994
# 433/994
# 434/994
# 435/994
# 436/994
# 437/994
# 438/994
# 439/994
# 440/994
# 441/994
# 442/994
# 443/994
# 444/994
# 445/994
# 446/994
# 447/994
# 448/994
# 449/994
# 450/994
# 451/994
# 452/994
# 453/994
# 454/994
# 455/994
# 456/994
# 457/994
# 458/994
# 459/994
# 460/994
# 461/994
# 462/994
# 463/994
# 464/994
# 465/994
# 466/994
# 467/994
# 468/994
# 469/994
# 470/994
# 471/994
# 472/994
# 473/994
# 474/994
# 475/994
# 476/994
# 477/994
# 478/994
# 479/994
# 480/994
# 481/994
# 482/994
# 483/994
# 484/994
# 485/994
# 486/994
# 487/994
# 488/994
# 489/994
# 490/994
# 491/994
# 492/994
# 493/994
# 494/994
# 495/994
# 496/994
# 497/994
# 498/994
# 499/994
# 500/994
# 501/994
# 502/994
# 503/994
# 504/994
# 505/994
# 506/994
# 507/994
# 508/994
# 509/994
# 510/994
# 511/994
# 512/994
# 513/994
# 514/994
# 515/994
# 516/994
# 517/994
# 518/994
# 519/994
# 520/994
# 521/994
# 522/994
# 523/994
# 524/994
# 525/994
# 526/994
# 527/994
# 528/994
# 529/994
# 530/994
# 531/994
# 532/994
# 533/994
# 534/994
# 535/994
# 536/994
# 537/994
# 538/994
# 539/994
# 540/994
# 541/994
# 542/994
# 543/994
# 544/994
# 545/994
# 546/994
# 547/994
# 548/994
# 549/994
# 550/994
# 551/994
# 552/994
# 553/994
# 554/994
# 555/994
# 556/994
# 557/994
# 558/994
# 559/994
# 560/994
# 561/994
# 562/994
# 563/994
# 564/994
# 565/994
# 566/994
# 567/994
# 568/994
# 569/994
# 570/994
# 571/994
# 572/994
# 573/994
# 574/994
# 575/994
# 576/994
# 577/994
# 578/994
# 579/994
# 580/994
# 581/994
# 582/994
# 583/994
# 584/994
# 585/994
# 586/994
# 587/994
# 588/994
# 589/994
# 590/994
# 591/994
# 592/994
# 593/994
# 594/994
# 595/994
# 596/994
# 597/994
# 598/994
# 599/994
# 600/994
# 601/994
# 602/994
# 603/994
# 604/994
# 605/994
# 606/994
# 607/994
# 608/994
# 609/994
# 610/994
# 611/994
# 612/994
# 613/994
# 614/994
# 615/994
# 616/994
# 617/994
# 618/994
# 619/994
# 620/994
# 621/994
# 622/994
# 623/994
# 624/994
# 625/994
# 626/994
# 627/994
# 628/994
# 629/994
# 630/994
# 631/994
# 632/994
# 633/994
# 634/994
# 635/994
# 636/994
# 637/994
# 638/994
# 639/994
# 640/994
# 641/994
# 642/994
# 643/994
# 644/994
# 645/994
# 646/994
# 647/994
# 648/994
# 649/994
# 650/994
# 651/994
# 652/994
# 653/994
# 654/994
# 655/994
# 656/994
# 657/994
# 658/994
# 659/994
# 660/994
# 661/994
# 662/994
# 663/994
# 664/994
# 665/994
# 666/994
# 667/994
# 668/994
# 669/994
# 670/994
# 671/994
# 672/994
# 673/994
# 674/994
# 675/994
# 676/994
# 677/994
# 678/994
# 679/994
# 680/994
# 681/994
# 682/994
# 683/994
# 684/994
# 685/994
# 686/994
# 687/994
# 688/994
# 689/994
# 690/994
# 691/994
# 692/994
# 693/994
# 694/994
# 695/994
# 696/994
# 697/994
# 698/994
# 699/994
# 700/994
# 701/994
# 702/994
# 703/994
# 704/994
# 705/994
# 706/994
# 707/994
# 708/994
# 709/994
# 710/994
# 711/994
# 712/994
# 713/994
# 714/994
# 715/994
# 716/994
# 717/994
# 718/994
# 719/994
# 720/994
# 721/994
# 722/994
# 723/994
# 724/994
# 725/994
# 726/994
# 727/994
# 728/994
# 729/994
# 730/994
# 731/994
# 732/994
# 733/994
# 734/994
# 735/994
# 736/994
# 737/994
# 738/994
# 739/994
# 740/994
# 741/994
# 742/994
# 743/994
# 744/994
# 745/994
# 746/994
# 747/994
# 748/994
# 749/994
# 750/994
# 751/994
# 752/994
# 753/994
# 754/994
# 755/994
# 756/994
# 757/994
# 758/994
# 759/994
# 760/994
# 761/994
# 762/994
# 763/994
# 764/994
# 765/994
# 766/994
# 767/994
# 768/994
# 769/994
# 770/994
# 771/994
# 772/994
# 773/994
# 774/994
# 775/994
# 776/994
# 777/994
# 778/994
# 779/994
# 780/994
# 781/994
# 782/994
# 783/994
# 784/994
# 785/994
# 786/994
# 787/994
# 788/994
# 789/994
# 790/994
# 791/994
# 792/994
# 793/994
# 794/994
# 795/994
# 796/994
# 797/994
# 798/994
# 799/994
# 800/994
# 801/994
# 802/994
# 803/994
# 804/994
# 805/994
# 806/994
# 807/994
# 808/994
# 809/994
# 810/994
# 811/994
# 812/994
# 813/994
# 814/994
# 815/994
# 816/994
# 817/994
# 818/994
# 819/994
# 820/994
# 821/994
# 822/994
# 823/994
# 824/994
# 825/994
# 826/994
# 827/994
# 828/994
# 829/994
# 830/994
# 831/994
# 832/994
# 833/994
# 834/994
# 835/994
# 836/994
# 837/994
# 838/994
# 839/994
# 840/994
# 841/994
# 842/994
# 843/994
# 844/994
# 845/994
# 846/994
# 847/994
# 848/994
# 849/994
# 850/994
# 851/994
# 852/994
# 853/994
# 854/994
# 855/994
# 856/994
# 857/994
# 858/994
# 859/994
# 860/994
# 861/994
# 862/994
# 863/994
# 864/994
# 865/994
# 866/994
# 867/994
# 868/994
# 869/994
# 870/994
# 871/994
# 872/994
# 873/994
# 874/994
# 875/994
# 876/994
# 877/994
# 878/994
# 879/994
# 880/994
# 881/994
# 882/994
# 883/994
# 884/994
# 885/994
# 886/994
# 887/994
# 888/994
# 889/994
# 890/994
# 891/994
# 892/994
# 893/994
# 894/994
# 895/994
# 896/994
# 897/994
# 898/994
# 899/994
# 900/994
# 901/994
# 902/994
# 903/994
# 904/994
# 905/994
# 906/994
# 907/994
# 908/994
# 909/994
# 910/994
# 911/994
# 912/994
# 913/994
# 914/994
# 915/994
# 916/994
# 917/994
# 918/994
# 919/994
# 920/994
# 921/994
# 922/994
# 923/994
# 924/994
# 925/994
# 926/994
# 927/994
# 928/994
# 929/994
# 930/994
# 931/994
# 932/994
# 933/994
# 934/994
# 935/994
# 936/994
# 937/994
# 938/994
# 939/994
# 940/994
# 941/994
# 942/994
# 943/994
# 944/994
# 945/994
# 946/994
# 947/994
# 948/994
# 949/994
# 950/994
# 951/994
# 952/994
# 953/994
# 954/994
# 955/994
# 956/994
# 957/994
# 958/994
# 959/994
# 960/994
# 961/994
# 962/994
# 963/994
# 964/994
# 965/994
# 966/994
# 967/994
# 968/994
# 969/994
# 970/994
# 971/994
# 972/994
# 973/994
# 974/994
# 975/994
# 976/994
# 977/994
# 978/994
# 979/994
# 980/994
# 981/994
# 982/994
# 983/994
# 984/994
# 985/994
# 986/994
# 987/994
# 988/994
# 989/994
# 990/994
# 991/994
# 992/994
# 993/994
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\2603445249.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prp_f['hpt_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\2603445249.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prp_f['lpt_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\2603445249.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prp_f['fan_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\2603445249.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prp_f['hpc_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
# C:\Users\admin\AppData\Local\Temp\ipykernel_17048\2603445249.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prp_f['lpc_yn_shift1'].loc[df_prp_f['cycle']==1] = 0
